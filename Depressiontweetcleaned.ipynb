# %% [markdown]
# Dataset : https://www.kaggle.com/fedesoriano/stroke-prediction-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
(df.isnull().sum()/len(df)) *100
# Out:
# id                   0.000000
# gender               0.000000
# age                  0.000000
# hypertension         0.000000
# heart_disease        0.000000
# ever_married         0.000000
# work_type            0.000000
# Residence_type       0.000000
# avg_glucose_level    0.000000
# bmi                  3.933464
# smoking_status       0.000000
# stroke               0.000000
# dtype: float64

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Username = "txtdariojoll"
c.Limit = 20
# Run
twint.run.Search(c)
# Out:
# 1463381245086224385 2021-11-24 12:37:31 +0700 <txtdariojoll> Mak bapak nya ada masalah apa si  https://t.co/Rp2uJGu4UF
# 1463380408393822216 2021-11-24 12:34:12 +0700 <txtdariojoll> Promo Gopay x Gofood Flash Sale 🗓️ Berlaku 24 November 2021  ⏰ 14:00-16:00  Flash Sale Aneka Makanan  Diskon 50% maksimal Rp20.000 berlaku untuk pembayaran menggunakan Gopay dan Gopaylater   Outletnya banyak, bisa cek disini selengkapnya:  https://t.co/OSybSa6lwH  https://t.co/FK2L4VUoLg
# 1462804966389665795 2021-11-22 22:27:36 +0700 <txtdariojoll> @dpawww Biasa lah, perkara mental Ng...
# 1462804846516453381 2021-11-22 22:27:07 +0700 <txtdariojoll> @lempung_sawah What do you expect sama mie ayam 10k anjir😩
# 1462788879061184518 2021-11-22 21:23:40 +0700 <txtdariojoll> 🤡  https://t.co/WQBClbXqPi
# 1462785636767649796 2021-11-22 21:10:47 +0700 <txtdariojoll> Mana insentif shopefood sekarang malah turun😩 Jabodetabek 6(20)-9(30)-12(42) hadeh..
# ...

# %%
config = twint.Config()
config.Search = "depressed"
config.Limit = 200
config.Since = "2021-11-01"
config.Until = "2021-11-22"
config.Lang = ""
config.Pandas = "True"
# config.Store_csv = True
config.Custom = ["id", "username", "tweet"]
# config.Output = "twitter.csv"
twint.run.Search(config)
# Out:
# 1462571508908318723 2021-11-22 06:59:55 +0700 <BIGDREW_> Depressed.
# 1462571503665381376 2021-11-22 06:59:54 +0700 <zel_daaa> every time around my birthday I get really depressed. I was so sad last night and my sister was like N O P E get up you’re going out. When it was her night to go out and my day to baby sit. But it did make me feel better and I thank her for that 🥺
# 1462571496539308038 2021-11-22 06:59:52 +0700 <itstheGIRLLLLLL> I hate the events leading up to my period I be so depressed and tired  😩🥺😂
# 1462571486582083589 2021-11-22 06:59:50 +0700 <hellohahanarf> @pghsciencenerd I was in my mid 20s and just knew that depressed area was not for us. I'm so sorry you had it that rough and am beyond grateful for the you of today. You are a damn fine human in despite of the shit.
# 1462571439245119493 2021-11-22 06:59:39 +0700 <SharonP79767497> @CitizenJSegura I'm just depressed.  And old. But I don't hardly sleep anymore
# ...

# %%
c
# Out:
# Config(Username='txtdariojoll', User_id='1239257360700305408', Search=None, Lookup=False, Geo='', Location=False, Near=None, Lang=None, Output=None, Elasticsearch=None, Year=None, Since=None, Until=None, Email=None, Phone=None, Verified=False, Store_csv=False, Store_json=False, Show_hashtags=False, Show_cashtags=False, Limit=20, Count=None, Stats=False, Database=None, To=None, Debug=False, Essid='', Profile=False, Followers=False, Following=False, Favorites=False, TwitterSearch=True, User_full=False, Store_object=False, Store_object_tweets_list=None, Store_object_users_list=None, Store_object_follow_list=None, Pandas_type=None, Pandas=False, Index_tweets='twinttweets', Index_follow='twintgraph', Index_users='twintuser', Retries_count=10, Resume=None, Images=False, Videos=False, Media=False, Replies=False, Pandas_clean=True, Lowercase=True, Pandas_au=True, Proxy_host='', Proxy_port=0, Proxy_type=None, Tor_control_port=9051, Tor_control_password=None, Retweets=False, Query=None, Hide_o
# ...

# %%
def test():
    return twint.output.panda.Tweets_df.columns

def twint_to_pdf(columns):
    return twint.output.panda.Tweets_df[columns]


data_twitter = twint_to_pdf(['date','username','tweet'])
print(data_twitter)

data_twitter.to_csv("Depressiontweet.csv",index = False)
# Out:
#                     date         username  \
# 0    2021-11-22 06:59:49       carryme0ut
# 1    2021-11-22 06:59:45    HELENNMCCRORY
# 2    2021-11-22 06:59:37  missesmysteries
# 3    2021-11-22 06:59:36     ambahatesyou
# 4    2021-11-22 06:59:20     sengulfndklr
# ..                   ...              ...
# 208  2021-11-22 06:41:50         ICHIRUKl
# 209  2021-11-22 06:41:48  HeroOfEquestria
# 210  2021-11-22 06:41:41          Thorzul
# 211  2021-11-22 06:41:27  ThatBitchStevie
# 212  2021-11-22 06:41:25  AlbertInMyPujol
#
#                                                  tweet
# 0    starting to think that I not only have adhd an...
# 1      depression for the tl   https://t.co/bQq1Tsq6xB
# 2    @Nerdy_Addict from childhood abuse. My therapi...
# 3         post show depression is the worst thing ever
# 4    Lemme just get xanax and I’ll be sleeping like...
# ..                                                 ...
# 208  Depression turned into anger I need to go runn...
# ...

# %%
test = pd.read_csv("Depressiontweet.csv")
test.head()
# Out:
#                   date         username  \
# 0  2021-11-22 06:59:49       carryme0ut
# 1  2021-11-22 06:59:45    HELENNMCCRORY
# 2  2021-11-22 06:59:37  missesmysteries
# 3  2021-11-22 06:59:36     ambahatesyou
# 4  2021-11-22 06:59:20     sengulfndklr
#
#                                                tweet
# 0  starting to think that I not only have adhd an...
# 1    depression for the tl   https://t.co/bQq1Tsq6xB
# 2  @Nerdy_Addict from childhood abuse. My therapi...
# 3       post show depression is the worst thing ever
# 4  Lemme just get xanax and I’ll be sleeping like...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-8e7b9895361f> in <module>
# ----> 1 columns
#
# NameError: name 'columns' is not defined
